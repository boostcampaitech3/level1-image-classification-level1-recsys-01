# %%
import csv
import pandas as pd
from PIL import Image
test = pd.read_csv("input/data/train/train.csv")
test.head()
# Out:
#        id  gender   race  age                    path
# 0  000001  female  Asian   45  000001_female_Asian_45
# 1  000002  female  Asian   52  000002_female_Asian_52
# 2  000004    male  Asian   54    000004_male_Asian_54
# 3  000005  female  Asian   58  000005_female_Asian_58
# 4  000006  female  Asian   59  000006_female_Asian_59

# %%
img = Image.open("data/train/images/000001_female_Asian_45/mask1.jpg")
img2 = transforms.RandomRotation(30)(img)
img3 = transforms.RandomHorizontalFlip(0.5)(img)
# Out:
# <PIL.Image.Image image mode=RGB size=384x512 at 0x7F855B047B80>

# %%
# Out:
# 1

# %%
import random
f = open("input/data/train/train.csv")
name = 0

for i in csv.reader(f):
    if name == 0:
        name += 1
        continue
    for j in range(1,4):
        try:
            img = Image.open(f"input/data/train/images/{i[4]}/mask{j}.jpg")
            a = random.randint(0,30)
            inverted_image = transforms.RandomRotation(a)(img)
            inverted_image.save(f"input/data/train/images/{i[4]}/mask{j*7+2}.jpg")
            rotated_image = transforms.RandomHorizontalFlip(0.5)(img)
            rotated_image.save(f"input/data/train/images/{i[4]}/mask{j*7+3}.jpg")
        except:
            continue
    try:
        img = Image.open(f"input/data/train/images/{i[4]}/incorrect_mask.jpg")
        a = random.randint(0,30)
        inverted_image = transforms.RandomRotation(a)(img)
        inverted_image.save(f"input/data/train/images/{i[4]}/incorrect_mask2.jpg")
        img = Image.open(f"input/data/train/images/{i[4]}/normal.jpg")
        rotated_image = transforms.RandomHorizontalFlip(0.5)(img)
        rotated_image.save(f"input/data/train/images/{i[4]}/normal2.jpg")
    except:
        continue

# %%
import random
f = open("input/data/train/train.csv")
name = 0

for i in csv.reader(f):
    if name == 0:
        name += 1
        continue
    try:
        img = Image.open(f"input/data/train/images/{i[4]}/incorrect_mask.jpg")
        a = random.randint(0,30)
        rotated_image = transforms.RandomHorizontalFlip(0.5)(img)
        rotated_image.save(f"input/data/train/images/{i[4]}/incorrect_mask3.jpg")
        
        img = Image.open(f"input/data/train/images/{i[4]}/normal.jpg")
        inverted_image = transforms.RandomRotation(a)(img)
        inverted_image.save(f"input/data/train/images/{i[4]}/normal3.jpg")
    except:
        continue
